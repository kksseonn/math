# %% [markdown]
# <h1>Лабораторная работа №4.<span class="tocSkip"></span></h1>
# <h2>Часть 1</h2>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Найдите оценки параметров линейной модели   зависимости ЗАРПЛАТЫ от фактора Z.
